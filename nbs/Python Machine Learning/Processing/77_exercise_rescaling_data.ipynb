# %% [markdown]
# ## Exercise: Rescaling data

# %% [markdown]
# Here's a quiz about rescaling data in data analysis with Python:
#
# 1. What is rescaling data in the context of data analysis?
#
# a) Converting data into a different data type
# b) Adjusting the scale or range of data values
# c) Deleting outliers from the dataset
# d) Adding noise to the dataset
#
# 2. Which of the following methods is commonly used for rescaling numerical data to a range between 0 and 1 in Python?
#
# a) Standardization
# b) Normalization
# c) Min-Max Scaling
# d) Robust Scaling
#
# 3. In Python, which library provides functions for rescaling data?
#
# a) NumPy
# b) Pandas
# c) Scikit-learn
# d) Matplotlib
#
# 4. What is the purpose of rescaling data before applying machine learning algorithms?
#
# a) To speed up the training process
# b) To make the data visually appealing
# c) To ensure that all features contribute equally to the model
# d) To reduce overfitting
#
# 5. Which of the following statements about Min-Max Scaling is true?
#
# a) It preserves the mean and standard deviation of the original data.
# b) It is not suitable for data with outliers.
# c) It transforms data to have a mean of 0 and a standard deviation of 1.
# d) It scales data to a specified range, typically between 0 and 1.
#
# 6. What does the Min-Max Scaling formula look like for rescaling a feature `x` to the range `[a, b]`?
#
# a) `x_prime = (x - np.mean(x)) / np.std(x)`
# b) `x_prime = (x - np.min(x)) / (np.max(x) - np.min(x)) * (b - a) + a`
# c) `x_prime = x - np.mean(x)`
# d) `x_prime = (x - np.min(x)) / (np.max(x) - np.min(x))`
#
# Assuming you're using NumPy (`np`) for calculations in Python.
#
# 7. Which rescaling technique is more sensitive to outliers?
#
# a) Min-Max Scaling
# b) Standardization
# c) Robust Scaling
# d) Normalization
#
# 8. When should you use Standardization over Min-Max Scaling?
#
# a) When the data has a clear minimum and maximum value.
# b) When the distribution of the data is not Gaussian (normal).
# c) When preserving the relationships between data points is important.
# d) When the data contains outliers.
#
# 9. Which Python library provides the `MinMaxScaler` and `StandardScaler` classes for rescaling data?
#
# a) NumPy
# b) Pandas
# c) Scikit-learn
# d) Matplotlib
#
# 10. Which function is used to perform Min-Max Scaling in scikit-learn?
#
# a) `minmax_scale()`
# b) `MinMaxScaler()`
# c) `min_max_scaling()`
# d) `scale()`

# %% [markdown]
# #### Do you seriously want to learn Programming and Data Analysis with Python?
#
# If you’re serious about learning Programming, Data Analysis with Python and getting prepared for Data Science roles, I highly encourage you to enroll in my Programming for Data Science Course, which I've taught to hundreds of students. Don’t waste your time following disconnected, outdated tutorials
#
# My Complete Programming for Data Science Course has everything you need in one place.
#
# The course offers:
#
# - Duration: Usually 3-4 months
# - Sessions: Four times a week (one on one)
# - Location: Online or/and at UMF House, Sir Apollo Kagwa Road
#
# What you'l learn:
#
# - Fundamentals of programming
# - Data manipulation and analysis
# - Visualization techniques
# - Introduction to machine learning
# - Database Management with SQL (optional)
# - Web Development with Django (optional)
#
# Best
#
# Juma Shafara
#
# Data Scientist, Instructor
#
# jumashafara0@gmail.com / dataideaorg@gmail.com
#
# +256701520768 / +256771754118
